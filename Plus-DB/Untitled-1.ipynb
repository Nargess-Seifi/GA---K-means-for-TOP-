# %%
# open a csv file and make it a df

import pandas as pd
import numpy as np

# open the csv file
df = pd.read_csv('shiraz_city_pois_attraction_modified_OH_____.csv')

# %%
df
# Out:
#                                             name  \
# 0                             eram-garden-shiraz
# 1              natural-history-technology-museum
# 2               afif-abad-garden-military-museum
# 3                           persepolis-of-shiraz
# 4                    nasir-al-mulk-mosque-shiraz
# ..                                           ...
# 178                            besat-park-shiraz
# 179                     baba-abr-icecream-shiraz
# 180                       salamat-walkway-shiraz
# 181                taknaz-shopping-center-shiraz
# 182  negin-fars-shopping-center-adel-abad-shiraz
#
#                          coordinates  open_time  close_time  spending_time  \
# 0           [29.6360623, 52.5251428]        480        1230            120
# 1           [29.5925335, 52.5721767]        480         840            120
# 2           [29.6231997, 52.4983724]        540        1080            120
# ...

# %%
type(df['coordinates'][0])
# Out:
# str
